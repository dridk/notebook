# %%
# !pip install PyVCF3
# !pip install tqdm
# !pip install altair

import ftplib
import pandas as pd 
import re
import vcf 
import os
import altair as alt

from glob import glob
from tqdm.notebook import tqdm

# %% [markdown]
# ## Analyse de l'évolution des données clinvar dans le temps
#
# Je récupère tous les VCFs de l'historique de clinvar et je fais du comptage.
# https://ftp.ncbi.nlm.nih.gov/pub/clinvar/vcf_GRCh38/archive_2.0/

# %%
def get_clinvar_urls(year:int)->list:
    """Récupère l'ensemble des URLS des VCF pour une date donnée"""
    SERVER = "ftp.ncbi.nlm.nih.gov"
    PATH=f"/pub/clinvar/vcf_GRCh38/archive_2.0/{year}"
    f = ftplib.FTP()
    f.connect(SERVER)
    f.login()
    f.cwd(PATH)

    dir_list = []
    f.dir(dir_list.append)

    urls = []
    for item in dir_list:
        match = re.search(r"(\w+\d+\.vcf.gz)$", item )
        if match:
            urls.append(f"{SERVER}/{PATH}/{match.group(1)}")

    return urls

# %%
# On génère une liste de toutes les VCFs entre 2017 et 2022

all_urls = []
for year in range(2017,2023):
    all_urls += get_clinvar_paths(year)
    
all_urls = pd.Series(all_urls)
all_urls.to_csv("clinvar_urls.csv", index=None, header=None)
all_urls
# Out:
# 0      ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 1      ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 2      ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 3      ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 4      ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
#                              ...
# 200    ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 201    ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 202    ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 203    ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# 204    ftp.ncbi.nlm.nih.gov//pub/clinvar/vcf_GRCh38/a...
# Length: 205, dtype: object

# %%
# On les télécharge tous en parallele ! C'est pas gros 
# !cat {clinvar_urls.csv}|parallel wget

# %%
# !ls *vcf.gz
# Out:
# clinvar_20170516.vcf.gz  clinvar_20191118.vcf.gz  clinvar_20210328.vcf.gz
# clinvar_20170615.vcf.gz  clinvar_20191125.vcf.gz  clinvar_20210404.vcf.gz
# clinvar_20170710.vcf.gz  clinvar_20191202.vcf.gz  clinvar_20210415.vcf.gz
# clinvar_20170802.vcf.gz  clinvar_20191219.vcf.gz  clinvar_20210418.vcf.gz
# clinvar_20170905.vcf.gz  clinvar_20191223.vcf.gz  clinvar_20210424.vcf.gz
# clinvar_20171002.vcf.gz  clinvar_20191231.vcf.gz  clinvar_20210501.vcf.gz
# clinvar_20171029.vcf.gz  clinvar_20200106.vcf.gz  clinvar_20210511.vcf.gz
# clinvar_20171203.vcf.gz  clinvar_20200113.vcf.gz  clinvar_20210517.vcf.gz
# clinvar_20171231.vcf.gz  clinvar_20200120.vcf.gz  clinvar_20210524.vcf.gz
# clinvar_20180128.vcf.gz  clinvar_20200127.vcf.gz  clinvar_20210529.vcf.gz
# clinvar_20180225.vcf.gz  clinvar_20200203.vcf.gz  clinvar_20210609.vcf.gz
# clinvar_20180401.vcf.gz  clinvar_20200210.vcf.gz  clinvar_20210615.vcf.gz
# clinvar_20180429.vcf.gz  clinvar_20200217.vcf.gz  clinvar_20210619.vcf.gz
# clinvar_20180603.vcf.gz  clinvar_20200224.vcf.gz  clinvar_20210626.vcf.gz
# clinvar_20180701.vcf.gz  clinvar_20200302.vcf.gz  clinvar_20210707.vcf.gz
# clinvar_20180729.vcf.gz  clinvar_20200310.vcf.gz  clinvar_20210710.vcf.gz
# clinvar_20180805.vcf.gz  clinvar_20200316.vcf.gz  clinvar_20210718.vcf.gz
# clinvar_20180930.vcf.gz  clinvar_20200327.vcf.gz  clinvar_20210724.vcf.gz
# clinvar_20181028.vcf.gz  clinvar_20200329.vcf.gz  clinvar_20210731.vcf.gz
# clinvar_20181202.vcf.gz  clinvar_20200407.vcf.gz  clinvar_20210807.vcf.gz
# clinvar_20181217.vcf.gz  clinvar_20200415.vcf.gz  clinvar_20210814.vcf.gz
# clinvar_20181225.vcf.gz  clinvar_20200419.vcf.gz  clinvar_20210821.vcf.gz
# clinvar_20190102.vcf.gz  clinvar_20200506.vcf.gz  clinvar_20210828.vcf.gz
# clinvar_20190108.vcf.gz  clinvar_20200513.vcf.gz  clinvar_20210908.vcf.gz
# clinvar_20190114.vcf.gz  clinvar_20200520.vcf.gz  clinvar_20210912.vcf.gz
# clinvar_20190123.vcf.gz  clinvar_20200602.vcf.gz  clinvar_20210919.vcf.gz
# clinvar_20190128.vcf.gz  clinvar_20200609.vcf.gz  clinvar_20210927.vcf.gz
# clinvar_20190204.vcf.gz  clinvar_20200615.vcf.gz  clinvar_20210929.vcf.gz
# clinvar_20190211.vcf.gz  clinvar_20200622.vcf.gz  clinvar_20211002.vcf.gz
# clinvar_20190219.vcf.gz  clinvar_20200629.vcf.gz  clinvar_20211009.vcf.gz
# clinvar_20190225.vcf.gz  clinvar_20200706.vcf.gz  clinvar_20211010.vcf.gz
# clinvar_20190305.vcf.gz  clinvar_20200716.vcf.gz  clinvar_20211016.vcf.gz
# clinvar_20190311.vcf.gz  clinvar_20200720.vcf.gz  clinvar_20211025.vcf.gz
# clinvar_20190319.vcf.gz  clinvar_20200728.vcf.gz  clinvar_20211030.vcf.gz
# clinvar_20190325.vcf.gz  clinvar_20200803.vcf.gz  clinvar_20211107.vcf.gz
# clinvar_20190403.vcf.gz  clinvar_20200810.vcf.gz  clinvar_20211113.vcf.gz
# clinvar_20190408.vcf.gz  clinvar_20200817.vcf.gz  clinvar_20211120.vcf.gz
# clinvar_20190417.vcf.gz  clinvar_20200824.vcf.gz  clinvar_20211130.vcf.gz
# clinvar_20190422.vcf.gz  clinvar_20200830.vcf.gz  clinvar_20211204.vcf.gz
# clinvar_20190429.vcf.gz  clinvar_20200905.vcf.gz  clinvar_20211212.vcf.gz
# clinvar_20190503.vcf.gz  clinvar_20200914.vcf.gz  clinvar_20211218.vcf.gz
# clinvar_20190506.vcf.gz  clinvar_20200919.vcf.gz  clinvar_20211225.vcf.gz
# clinvar_20190513.vcf.gz  clinvar_20200927.vcf.gz  clinvar_20220103.vcf.gz
# clinvar_20190520.vcf.gz  clinvar_20201003.vcf.gz  clinvar_20220109.vcf.gz
# clinvar_20190527.vcf.gz  clinvar_20201010.vcf.gz  clinvar_20220115.vcf.gz
# clinvar_20190603.vcf.gz  clinvar_20201020.vcf.gz  clinvar_20220122.vcf.gz
# clinvar_20190609.vcf.gz  clinvar_20201026.vcf.gz  clinvar_20220129.vcf.gz
# clinvar_20190618.vcf.gz  clinvar_20201031.vcf.gz  clinvar_20220205.vcf.gz
# clinvar_20190624.vcf.gz  clinvar_20201107.vcf.gz  clinvar_20220213.vcf.gz
# clinvar_20190701.vcf.gz  clinvar_20201114.vcf.gz  clinvar_20220222.vcf.gz
# clinvar_20190708.vcf.gz  clinvar_20201121.vcf.gz  clinvar_20220227.vcf.gz
# clinvar_20190715.vcf.gz  clinvar_20201128.vcf.gz  clinvar_20220306.vcf.gz
# clinvar_20190722.vcf.gz  clinvar_20201208.vcf.gz  clinvar_20220313.vcf.gz
# clinvar_20190731.vcf.gz  clinvar_20201212.vcf.gz  clinvar_20220320.vcf.gz
# clinvar_20190805.vcf.gz  clinvar_20201219.vcf.gz  clinvar_20220328.vcf.gz
# clinvar_20190815.vcf.gz  clinvar_20201226.vcf.gz  clinvar_20220403.vcf.gz
# clinvar_20190821.vcf.gz  clinvar_20210102.vcf.gz  clinvar_20220412.vcf.gz
# clinvar_20190828.vcf.gz  clinvar_20210110.vcf.gz  clinvar_20220416.vcf.gz
# clinvar_20190902.vcf.gz  clinvar_20210119.vcf.gz  clinvar_20220425.vcf.gz
# clinvar_20190909.vcf.gz  clinvar_20210123.vcf.gz  clinvar_20220430.vcf.gz
# clinvar_20190916.vcf.gz  clinvar_20210128.vcf.gz  clinvar_20220507.vcf.gz
# clinvar_20190923.vcf.gz  clinvar_20210131.vcf.gz  clinvar_20220517.vcf.gz
# clinvar_20191001.vcf.gz  clinvar_20210208.vcf.gz  clinvar_20220525.vcf.gz
# clinvar_20191003.vcf.gz  clinvar_20210213.vcf.gz  clinvar_20220528.vcf.gz
# clinvar_20191007.vcf.gz  clinvar_20210221.vcf.gz  clinvar_20220606.vcf.gz
# clinvar_20191013.vcf.gz  clinvar_20210302.vcf.gz  clinvar_20220611.vcf.gz
# clinvar_20191021.vcf.gz  clinvar_20210308.vcf.gz  clinvar_20220619.vcf.gz
# clinvar_20191105.vcf.gz  clinvar_20210315.vcf.gz  clinvar_20220620.vcf.gz
# clinvar_20191111.vcf.gz  clinvar_20210323.vcf.gz

# %%
## On parcours chaque VCF pour récupérer la date et des stats. Pour le moment que des comptage .
# A améliorer.. 
stat_df = []

for file in tqdm(glob("*vcf.gz")):
    match = re.search(r"clinvar_(\d+)\.vcf.gz", file)
    
    if match:
        date = match.group(1)
        total = !zcat {file}|grep -v "#"|wc -l 
        
        patho = !zcat {file}|grep -v "#"|grep "Pathogenic"|wc -l
        likely_path = !zcat {file}|grep -v "#"|grep "Likely_pathogenic"|wc -l
        likely_benign = !zcat {file}|grep -v "#"|grep "Likely_benign"|wc -l
        benign = !zcat {file}|grep -v "#"|grep "Benign"|wc -l
        vsi = !zcat {file}|grep -v "#"|grep "Uncertain_significance"|wc -l
        conflict = !zcat {file}|grep -v "#"|grep "Conflicting"|wc -l

        
        stat_df.append((date,int(total[0]),patho[0], likely_path[0], likely_benign[0],benign[0],vsi[0],conflict[0]))
    
            
        
stat_df = pd.DataFrame(stat_df, columns=["date","count","patho","likely_path","likely_benign","benign","vsi", "conflict"])
stat_df["date"] = pd.to_datetime(stat_df["date"])
stat_df
stat_df.to_csv("stat.csv", index=None, header=None)

# %%
# On anti-pivot la table et on fait un dessin 
df = stat_df.melt(id_vars="date")
alt.Chart(df).mark_line().encode(x="date",y="value",color="variable").properties(title="Nombre de variants dans clinvar")
# Out:
# alt.Chart(...)

# %%
alt.Chart(stat_df).mark_line().encode(x="date",y="count").properties(title="Nombre de variants dans clinvar")
# Out:
# alt.Chart(...)
